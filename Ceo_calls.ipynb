# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# Out:
# /content

# %%
# %cd 'drive/My Drive'
# Out:
# /content/drive/My Drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
text_file = open("data.txt", "r")
text = text_file.read()

# %%
text
# Out:
# "Good morning everyone and thanks for joining us\nI want to start our call today by looking back\n2016 was a transformative year for us\nTransformations are difficult, and this one was especially challenging\nWe started 2016 by resetting and focusing on why people use Twitter\nIt's the fastest way to see what's happening, and what everyone is talking about\nWe reset and refocused on our strengths, and we achieved one of the hardest things to do for a consumer services scale\nWe reversed and reaccelerated our usage\nWe're thrilled to report that daily active usage accelerated for the third quarter in a row, and we see that strong growth continuing\nWe did this by making the experience a little better every single day\nIt may have felt like we weren't changing much this past year, but those hundreds of little changes added up to more predictable and sustained growth we will now use as a foundation to be more inventive and to take bigger risks\nAnd that's exactly what we are now going t
# ...

# %%
def remove_newlines(filename):
    flist = open(filename).readlines()
    return [s.rstrip('\n') for s in flist]

print(remove_newlines("data.txt"))
# Out:
# ['Good morning everyone and thanks for joining us', 'I want to start our call today by looking back', '2016 was a transformative year for us', 'Transformations are difficult, and this one was especially challenging', 'We started 2016 by resetting and focusing on why people use Twitter', "It's the fastest way to see what's happening, and what everyone is talking about", 'We reset and refocused on our strengths, and we achieved one of the hardest things to do for a consumer services scale', 'We reversed and reaccelerated our usage', "We're thrilled to report that daily active usage accelerated for the third quarter in a row, and we see that strong growth continuing", 'We did this by making the experience a little better every single day', "It may have felt like we weren't changing much this past year, but those hundreds of little changes added up to more predictable and sustained growth we will now use as a foundation to be more inventive and to take bigger risks", "And that's exactly 
# ...

# %%
text = text.replace('\n', '.')

# %%
text
# Out:
# "Good morning everyone and thanks for joining us.I want to start our call today by looking back.2016 was a transformative year for us.Transformations are difficult, and this one was especially challenging.We started 2016 by resetting and focusing on why people use Twitter.It's the fastest way to see what's happening, and what everyone is talking about.We reset and refocused on our strengths, and we achieved one of the hardest things to do for a consumer services scale.We reversed and reaccelerated our usage.We're thrilled to report that daily active usage accelerated for the third quarter in a row, and we see that strong growth continuing.We did this by making the experience a little better every single day.It may have felt like we weren't changing much this past year, but those hundreds of little changes added up to more predictable and sustained growth we will now use as a foundation to be more inventive and to take bigger risks.And that's exactly what we are now going to do.We sai
# ...

# %%
import nltk
# Out:
# /usr/local/lib/python3.7/dist-packages/nltk/decorators.py:70: DeprecationWarning: `formatargspec` is deprecated since Python 3.5. Use `signature` and the `Signature` object directly
#   formatvalue=lambda value: "")[1:-1]
# /usr/local/lib/python3.7/dist-packages/scipy/io/matlab/mio5.py:98: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from .mio5_utils import VarReader5

# %%
from nltk import tokenize

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
lines=tokenize.sent_tokenize(text)
print(lines)
# Out:
# ["Good morning everyone and thanks for joining us.I want to start our call today by looking back.2016 was a transformative year for us.Transformations are difficult, and this one was especially challenging.We started 2016 by resetting and focusing on why people use Twitter.It's the fastest way to see what's happening, and what everyone is talking about.We reset and refocused on our strengths, and we achieved one of the hardest things to do for a consumer services scale.We reversed and reaccelerated our usage.We're thrilled to report that daily active usage accelerated for the third quarter in a row, and we see that strong growth continuing.We did this by making the experience a little better every single day.It may have felt like we weren't changing much this past year, but those hundreds of little changes added up to more predictable and sustained growth we will now use as a foundation to be more inventive and to take bigger risks.And that's exactly what we are now going to do.We sa
# ...

# %%
words=tokenize.word_tokenize(text)
print(words)
# Out:
# ['Good', 'morning', 'everyone', 'and', 'thanks', 'for', 'joining', 'us.I', 'want', 'to', 'start', 'our', 'call', 'today', 'by', 'looking', 'back.2016', 'was', 'a', 'transformative', 'year', 'for', 'us.Transformations', 'are', 'difficult', ',', 'and', 'this', 'one', 'was', 'especially', 'challenging.We', 'started', '2016', 'by', 'resetting', 'and', 'focusing', 'on', 'why', 'people', 'use', 'Twitter.It', "'s", 'the', 'fastest', 'way', 'to', 'see', 'what', "'s", 'happening', ',', 'and', 'what', 'everyone', 'is', 'talking', 'about.We', 'reset', 'and', 'refocused', 'on', 'our', 'strengths', ',', 'and', 'we', 'achieved', 'one', 'of', 'the', 'hardest', 'things', 'to', 'do', 'for', 'a', 'consumer', 'services', 'scale.We', 'reversed', 'and', 'reaccelerated', 'our', 'usage.We', "'re", 'thrilled', 'to', 'report', 'that', 'daily', 'active', 'usage', 'accelerated', 'for', 'the', 'third', 'quarter', 'in', 'a', 'row', ',', 'and', 'we', 'see', 'that', 'strong', 'growth', 'continuing.We', 'did', 'thi
# ...

# %%
#stemming gives words which might not have meaning sometimes so do lemmetization
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
stem_words=[]
for word in words:
    root_word= ps.stem(word)
    stem_words.append(root_word)
print("After stemming -", stem_words)
# Out:
# After stemming - ['good', 'morn', 'everyon', 'and', 'thank', 'for', 'join', 'us.i', 'want', 'to', 'start', 'our', 'call', 'today', 'by', 'look', 'back.2016', 'wa', 'a', 'transform', 'year', 'for', 'us.transform', 'are', 'difficult', ',', 'and', 'thi', 'one', 'wa', 'especi', 'challenging.w', 'start', '2016', 'by', 'reset', 'and', 'focus', 'on', 'whi', 'peopl', 'use', 'twitter.it', "'s", 'the', 'fastest', 'way', 'to', 'see', 'what', "'s", 'happen', ',', 'and', 'what', 'everyon', 'is', 'talk', 'about.w', 'reset', 'and', 'refocus', 'on', 'our', 'strength', ',', 'and', 'we', 'achiev', 'one', 'of', 'the', 'hardest', 'thing', 'to', 'do', 'for', 'a', 'consum', 'servic', 'scale.w', 'revers', 'and', 'reacceler', 'our', 'usage.w', "'re", 'thrill', 'to', 'report', 'that', 'daili', 'activ', 'usag', 'acceler', 'for', 'the', 'third', 'quarter', 'in', 'a', 'row', ',', 'and', 'we', 'see', 'that', 'strong', 'growth', 'continuing.w', 'did', 'thi', 'by', 'make', 'the', 'experi', 'a', 'littl', 'better', 
# ...

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer
ps = PorterStemmer()
wml = WordNetLemmatizer()
lemma_words=[]
for word in words:
    tokens = wml.lemmatize(word)
    lemma_words.append(tokens)
print("After lemmatization", lemma_words)
# Out:
# After lemmatization ['Good', 'morning', 'everyone', 'and', 'thanks', 'for', 'joining', 'us.I', 'want', 'to', 'start', 'our', 'call', 'today', 'by', 'looking', 'back.2016', 'wa', 'a', 'transformative', 'year', 'for', 'us.Transformations', 'are', 'difficult', ',', 'and', 'this', 'one', 'wa', 'especially', 'challenging.We', 'started', '2016', 'by', 'resetting', 'and', 'focusing', 'on', 'why', 'people', 'use', 'Twitter.It', "'s", 'the', 'fastest', 'way', 'to', 'see', 'what', "'s", 'happening', ',', 'and', 'what', 'everyone', 'is', 'talking', 'about.We', 'reset', 'and', 'refocused', 'on', 'our', 'strength', ',', 'and', 'we', 'achieved', 'one', 'of', 'the', 'hardest', 'thing', 'to', 'do', 'for', 'a', 'consumer', 'service', 'scale.We', 'reversed', 'and', 'reaccelerated', 'our', 'usage.We', "'re", 'thrilled', 'to', 'report', 'that', 'daily', 'active', 'usage', 'accelerated', 'for', 'the', 'third', 'quarter', 'in', 'a', 'row', ',', 'and', 'we', 'see', 'that', 'strong', 'growth', 'continuing.W
# ...

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# %%
#decomposing the paragraph into words
from nltk.tokenize import word_tokenize
words = lemma_words
from nltk.corpus import stopwords
filter_words = []
Stopwords = (stopwords.words('english'))
#removing the stop-words
for w in words:
    if w not in Stopwords:
         filter_words.append(w)
#print("Total words after removing stop-words-",len(filter_words))
print(filter_words)
# Out:
# ['Good', 'morning', 'everyone', 'thanks', 'joining', 'us.I', 'want', 'start', 'call', 'today', 'looking', 'back.2016', 'wa', 'transformative', 'year', 'us.Transformations', 'difficult', ',', 'one', 'wa', 'especially', 'challenging.We', 'started', '2016', 'resetting', 'focusing', 'people', 'use', 'Twitter.It', "'s", 'fastest', 'way', 'see', "'s", 'happening', ',', 'everyone', 'talking', 'about.We', 'reset', 'refocused', 'strength', ',', 'achieved', 'one', 'hardest', 'thing', 'consumer', 'service', 'scale.We', 'reversed', 'reaccelerated', 'usage.We', "'re", 'thrilled', 'report', 'daily', 'active', 'usage', 'accelerated', 'third', 'quarter', 'row', ',', 'see', 'strong', 'growth', 'continuing.We', 'making', 'experience', 'little', 'better', 'every', 'single', 'day.It', 'may', 'felt', 'like', "n't", 'changing', 'much', 'past', 'year', ',', 'hundred', 'little', 'change', 'added', 'predictable', 'sustained', 'growth', 'use', 'foundation', 'inventive', 'take', 'bigger', 'risks.And', "'s", 'e
# ...

# %%
def listToString(s): 
    
    # initialize an empty string
    str1 = " " 
    
    # return string  
    return (str1.join(s))
        
        
# Driver code    

print(listToString(filter_words))

cleandata = listToString(filter_words)
# Out:
# Good morning everyone thanks joining us.I want start call today looking back.2016 wa transformative year us.Transformations difficult , one wa especially challenging.We started 2016 resetting focusing people use Twitter.It 's fastest way see 's happening , everyone talking about.We reset refocused strength , achieved one hardest thing consumer service scale.We reversed reaccelerated usage.We 're thrilled report daily active usage accelerated third quarter row , see strong growth continuing.We making experience little better every single day.It may felt like n't changing much past year , hundred little change added predictable sustained growth use foundation inventive take bigger risks.And 's exactly going do.We said last call revenue growth lag usage.As see number outlook , ha proven case.Our advertiser need approach apply consumer service , reset focus strengths.This mean clearly differentiating complementing Twitter 's real-time nature , proving advertiser Twitter easy work custome
# ...

# %%
f = open("cleandatafile.txt", "w")
f.write(cleandata)
f.close()

# %%
f = open("cleandatafile.txt", "r")
print(f.read())
# Out:
# Good morning everyone thanks joining us.I want start call today looking back.2016 wa transformative year us.Transformations difficult , one wa especially challenging.We started 2016 resetting focusing people use Twitter.It 's fastest way see 's happening , everyone talking about.We reset refocused strength , achieved one hardest thing consumer service scale.We reversed reaccelerated usage.We 're thrilled report daily active usage accelerated third quarter row , see strong growth continuing.We making experience little better every single day.It may felt like n't changing much past year , hundred little change added predictable sustained growth use foundation inventive take bigger risks.And 's exactly going do.We said last call revenue growth lag usage.As see number outlook , ha proven case.Our advertiser need approach apply consumer service , reset focus strengths.This mean clearly differentiating complementing Twitter 's real-time nature , proving advertiser Twitter easy work custome
# ...

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
wordcloud = WordCloud( background_color="white").generate(text)

# %%
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
cleandata
# Out:
# "Good morning everyone thanks joining u I want start call today looking back 2016 wa transformative year u Transformations difficult , one wa especially challenging We started 2016 resetting focusing people use Twitter It 's fastest way see 's happening , everyone talking We reset refocused strength , achieved one hardest thing consumer service scale We reversed reaccelerated usage We 're thrilled report daily active usage accelerated third quarter row , see strong growth continuing We making experience little better every single day It may felt like n't changing much past year , hundred little change added predictable sustained growth use foundation inventive take bigger risk And 's exactly going We said last call revenue growth lag usage As see number outlook , ha proven case Our advertiser need approach apply consumer service , reset focus strength This mean clearly differentiating complementing Twitter 's real-time nature , proving advertiser Twitter easy work customer 2016 chall
# ...

# %% [markdown]
# ## TEXT SUMMARIZATIOM

# %%
sentence_list = nltk.sent_tokenize(cleandata)

# %%
sentence_list
# Out:
# ["Good morning everyone thanks joining u I want start call today looking back 2016 wa transformative year u Transformations difficult , one wa especially challenging We started 2016 resetting focusing people use Twitter It 's fastest way see 's happening , everyone talking We reset refocused strength , achieved one hardest thing consumer service scale We reversed reaccelerated usage We 're thrilled report daily active usage accelerated third quarter row , see strong growth continuing We making experience little better every single day It may felt like n't changing much past year , hundred little change added predictable sustained growth use foundation inventive take bigger risk And 's exactly going We said last call revenue growth lag usage As see number outlook , ha proven case Our advertiser need approach apply consumer service , reset focus strength This mean clearly differentiating complementing Twitter 's real-time nature , proving advertiser Twitter easy work customer 2016 chal
# ...

# %%
#First we create a word frequency 

word_frequencies = {}
for word in filter_words:
        if word not in word_frequencies.keys():
            word_frequencies[word] = 1
        else:
            word_frequencies[word] += 1

# %%
word_frequencies

# %%
maximum_freqeuncy = max(word_frequencies.values())

for word in word_frequencies.keys():
    word_frequencies[word] = (word_frequencies[word]/maximum_freqeuncy)

# %%
sentence_scores = {}
for sent in sentence_list:
    for word in nltk.word_tokenize(sent.lower()):
        if word in word_frequencies.keys():
            if len(sent.split(' ')) < 200:
                if sent not in sentence_scores.keys():
                    sentence_scores[sent] = word_frequencies[word]
                else:
                    sentence_scores[sent] += word_frequencies[word]

# %%
sentence_scores
# Out:
# {"On prior call , 've talked fact large-scale player digital advertising social advertising budget prior year That 's increased throughout 2016 .": 1.924369747899159}

# %% [markdown]
# Another way using spacy

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation
from heapq import nlargest

# %%
text_file = open("data.txt", "r")
text = text_file.read()

# %%
text = text.replace('\n','.')

# %%
def summarize(text, per):
    nlp = spacy.load('en_core_web_sm')
    doc= nlp(text)
    tokens=[token.text for token in doc]
    word_frequencies={}
    for word in doc:
        if word.text.lower() not in list(STOP_WORDS):
            if word.text.lower() not in punctuation:
                if word.text not in word_frequencies.keys():
                    word_frequencies[word.text] = 1
                else:
                    word_frequencies[word.text] += 1
    max_frequency=max(word_frequencies.values())
    for word in word_frequencies.keys():
        word_frequencies[word]=word_frequencies[word]/max_frequency
    sentence_tokens= [sent for sent in doc.sents]
    sentence_scores = {}
    for sent in sentence_tokens:
        for word in sent:
            if word.text.lower() in word_frequencies.keys():
                if sent not in sentence_scores.keys():                            
                    sentence_scores[sent]=word_frequencies[word.text.lower()]
                else:
                    sentence_scores[sent]+=word_frequencies[word.text.lower()]
    select_length=int(len(sentence_tokens)*per)
    summary=nlargest(select_length, sentence_scores,key=sentence_scores.get)
    final_summary=[word.text for word in summary]
    summary=''.join(final_summary)
    return summary

# %%
summarize(text,0.03)
# Out:
# "Now that we spent a year really going through and making sure that we reset the foundation on what we're executing, what our priorities are and how we execute from an engineering perspective, we have a lot more confidence that we can move a lot faster on bigger things because we have taken care of a lot of the things that were just not simple enough, and a lot of the (27:25) that we needed to address immediately, so that we could develop much faster and bring new experiences to life.He's been with the company for over two years and he's shown a lot of great promise and he led a lot of our effort to make sure that we're focused on the right initiatives to actually reaccelerate our growth and has proven a lot to the company and also to his team.It seems like there's still a lot of opportunity to see even more as we make it easier and easier for people to tweet, and we focus a lot more on topics that people want to talk about and participate with."
